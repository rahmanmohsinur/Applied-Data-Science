# %% [markdown]
# # **SpaceX  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
#  ## EDA with Visualization

# %% [markdown]
# In this notebook, we will predict if the Falcon 9 first stage will land successfully. SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars; other providers cost upward of 165 million dollars each, much of the savings is due to the fact that SpaceX can reuse the first stage.
#
# Here wou will perform Exploratory Data Analysis and Feature Engineering.

# %% [markdown]
# Most unsuccessful landings are planned. Space X performs a controlled landing in the oceans.

# %% [markdown]
#   ## Objectives
# Perform exploratory Data Analysis and Feature Engineering using `Pandas` and `Matplotlib`
#
# - Exploratory Data Analysis
# - Preparing Data  Feature Engineering

# %% [markdown]
# ----

# %% [markdown]
# Install the below libraries

# %%
# !pip install pandas
# !pip install numpy
# !pip install seaborn
# !pip install matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (1.26.4)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from seaborn) (2.2.2)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Downloading matplotlib-3.10.1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading contourpy-1.3.1-cp311-cp311-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading fonttools-4.57.0-cp311-cp311-win_amd64.whl.metadata (104 kB)
#      ---------------------------------------- 0.0/104.6 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/104.6 kB ? eta -:--:--
#      ---------- -------------------------- 30.7/104.6 kB 330.3 kB/s eta 0:00:01
#      ------------------------- ----------- 71.7/104.6 kB 491.5 kB/s eta 0:00:01
#      -----------------------------------  102.4/104.6 kB 658.3 kB/s eta 0:00:01
#      ------------------------------------ 104.6/104.6 kB 551.8 kB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    --------------------------------------- 294.9/294.9 kB 19.0 MB/s eta 0:00:00
# Downloading matplotlib-3.10.1-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------------- -------------------------- 2.6/8.1 MB 57.2 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.1 MB 58.8 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 64.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 51.6 MB/s eta 0:00:00
# Downloading contourpy-1.3.1-cp311-cp311-win_amd64.whl (219 kB)
#    ---------------------------------------- 0.0/219.8 kB ? eta -:--:--
#    --------------------------------------- 219.8/219.8 kB 13.1 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.57.0-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------  2.2/2.2 MB 68.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 46.7 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl (71 kB)
#    ---------------------------------------- 0.0/72.0 kB ? eta -:--:--
#    ---------------------------------------- 72.0/72.0 kB ? eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#    ---------------------------------------- 0.0/111.1 kB ? eta -:--:--
#    ---------------------------------------- 111.1/111.1 kB 6.3 MB/s eta 0:00:00
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.57.0 kiwisolver-1.4.8 matplotlib-3.10.1 pyparsing-3.2.3 seaborn-0.13.2
# Requirement already satisfied: matplotlib in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\rahma\anaconda3\envs\machinelearning\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ### Import Libraries and Define Auxiliary Functions

# %% [markdown]
# We will import the following libraries

# %%
# andas is a software library written for the Python programming language for data manipulation and analysis.
import pandas as pd
#NumPy is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays
import numpy as np
# Matplotlib is a plotting library for python and pyplot gives us a MatLab like plotting framework. We will use this in our plotter function to plot data.
import matplotlib.pyplot as plt
#Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics
import seaborn as sns

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# First, let's read the SpaceX dataset into a Pandas dataframe and print its summary

# %%
df=pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/dataset_part_2.csv")

# If you are unable to complete the previous lab correctly you can uncomment and load this csv

# df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/dataset_part_2.csv')

df.head(5)
# Out:
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010-06-04       Falcon 9  6104.959412   LEO  CCAFS SLC 40
# 1             2  2012-05-22       Falcon 9   525.000000   LEO  CCAFS SLC 40
# 2             3  2013-03-01       Falcon 9   677.000000   ISS  CCAFS SLC 40
# 3             4  2013-09-29       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013-12-03       Falcon 9  3170.000000   GTO  CCAFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 0    None None        1     False   False  False        NaN    1.0
# 1    None None        1     False   False  False        NaN    1.0
# 2    None None        1     False   False  False        NaN    1.0
# 3  False Ocean        1     False   False  False        NaN    1.0
# 4    None None        1     False   False  False        NaN    1.0
#
#    ReusedCount Serial   Longitude   Latitude  Class
# 0            0  B0003  -80.577366  28.561857      0
# 1            0  B0005  -80.577366  28.561857      0
# 2            0  B0007  -80.577366  28.561857      0
# 3            0  B1003 -120.610829  34.632093      0
# 4            0  B1004  -80.577366  28.561857      0

# %% [markdown]
# First, let's try to see how the `FlightNumber` (indicating the continuous launch attempts.) and `Payload` variables would affect the launch outcome.
#
# We can plot out the <code>FlightNumber</code> vs. <code>PayloadMass</code>and overlay the outcome of the launch. We see that as the flight number increases, the first stage is more likely to land successfully. The payload mass is also important; it seems the more massive the payload, the less likely the first stage will return.

# %%
sns.catplot(y="PayloadMass", x="FlightNumber", hue="Class", data=df, aspect = 5)
plt.xlabel("Flight Number",fontsize=20)
plt.ylabel("Pay load Mass (kg)",fontsize=20)
plt.show()

# %% [markdown]
# Next, let's drill down to each site visualize its detailed launch records.

# %% [markdown]
# ### Visualize the relationship between Flight Number and Launch Site

# %% [markdown]
# Use the function <code>catplot</code> to plot <code>FlightNumber</code> vs <code>LaunchSite</code>, set the  parameter <code>x</code>  parameter to <code>FlightNumber</code>,set the  <code>y</code> to <code>Launch Site</code> and set the parameter <code>hue</code> to <code>'class'</code>

# %%
# Plot a scatter point chart with x axis to be Flight Number and y axis to be the launch site, and hue to be the class value

# Visualize the relationship between Flight Number and Launch Site
sns.catplot(x="FlightNumber", y="LaunchSite", hue="Class", data=df, aspect=5, height=5)
plt.xlabel("Flight Number", fontsize=15)
plt.ylabel("Launch Site", fontsize=15)
plt.title("Flight Number vs Launch Site with Launch Outcome", fontsize=18)
plt.show()

# %% [markdown]
# Now try to explain the patterns you found in the Flight Number vs. Launch Site scatter point plots.

# %% [markdown]
# ### Visualize the relationship between Payload and Launch Site

# %% [markdown]
# We also want to observe if there is any relationship between launch sites and their payload mass.

# %%
# Plot a scatter point chart with x axis to be Pay Load Mass (kg) and y axis to be the launch site, and hue to be the class value

# Visualize the relationship between Payload Mass and Launch Site
sns.catplot(x="PayloadMass", y="LaunchSite", hue="Class", data=df, aspect=5, height=5)
plt.xlabel("Payload Mass (kg)", fontsize=20)
plt.ylabel("Launch Site", fontsize=20)
plt.title("Payload Mass vs Launch Site with Launch Outcome", fontsize=18)
plt.show()

# %% [markdown]
# Now if you observe Payload Vs. Launch Site scatter point chart you will find for the VAFB-SLC  launchsite there are no  rockets  launched for  heavypayload mass(greater than 10000).

# %% [markdown]
# ### Visualize the relationship between success rate of each orbit type

# %% [markdown]
# Next, we want to visually check if there are any relationship between success rate and orbit type.

# %% [markdown]
# Let's create a `bar chart` for the sucess rate of each orbit

# %%
# HINT use groupby method on Orbit column and get the mean of Class column

# Group by Orbit and calculate the mean success rate
orbit_success = df.groupby('Orbit')['Class'].mean().reset_index()

# Sort values for better readability
orbit_success_sorted = orbit_success.sort_values(by='Class', ascending=False)

# Plot the bar chart
plt.figure(figsize=(10,6))
sns.barplot(x='Orbit', y='Class', data=orbit_success_sorted, palette='viridis', hue='Orbit')
plt.xlabel('Orbit Type', fontsize=18)
plt.ylabel('Success Rate', fontsize=18)
plt.title('Success Rate by Orbit Type', fontsize=18)
plt.xticks(rotation=45)
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Analyze the ploted bar chart try to find which orbits have high sucess rate.

# %% [markdown]
# ### Visualize the relationship between FlightNumber and Orbit type

# %% [markdown]
# For each orbit, we want to see if there is any relationship between FlightNumber and Orbit type.

# %%
# Plot a scatter point chart with x axis to be FlightNumber and y axis to be the Orbit, and hue to be the class value

# Plot a scatter chart: Flight Number vs Orbit type
sns.catplot(x="FlightNumber", y="Orbit", hue="Class", data=df, aspect=5, height=5)
plt.xlabel("Flight Number", fontsize=18)
plt.ylabel("Orbit Type", fontsize=18)
plt.title("Flight Number vs Orbit Type with Launch Outcome", fontsize=21)
plt.show()

# %% [markdown]
# You should see that in the LEO orbit the Success appears related to the number of flights; on the other hand, there seems to be no relationship between flight number when in GTO orbit.

# %% [markdown]
# ### Visualize the relationship between Payload and Orbit type

# %% [markdown]
# Similarly, we can plot the Payload vs. Orbit scatter point charts to reveal the relationship between Payload and Orbit type

# %%
# Plot a scatter point chart with x axis to be Payload and y axis to be the Orbit, and hue to be the class value

# Scatter plot: Payload Mass vs Orbit, colored by launch success
sns.catplot(x="PayloadMass", y="Orbit", hue="Class", data=df, aspect=5, height=5)
plt.xlabel("Payload Mass (kg)", fontsize=18)
plt.ylabel("Orbit Type", fontsize=18)
plt.title("Payload Mass vs Orbit Type with Launch Outcome", fontsize=21)
plt.show()

# %% [markdown]
# With heavy payloads the successful landing or positive landing rate are more for Polar,LEO and ISS.
#
# However for GTO we cannot distinguish this well as both positive landing rate and negative landing(unsuccessful mission) are both there here.

# %% [markdown]
# ### Visualize the launch success yearly trend

# %% [markdown]
# We can plot a line chart with x axis to be <code>Year</code> and y axis to be average success rate, to get the average launch success trend.

# %% [markdown]
# The function will help you get the year from the date:

# %%
# Extract year from Date column
year = []
def Extract_year():
    for i in df["Date"]:
        year.append(i.split("-")[0])
    return year

Extract_year()
df['Year'] = year

# %%
# Plot a line chart with x axis to be the extracted year and y axis to be the success rate

# Convert Year to numeric type
df['Year'] = df['Year'].astype(int)

# Group by Year and compute the mean success rate
yearly_success = df.groupby('Year')['Class'].mean().reset_index()

# %%
# Plot the line chart
plt.figure(figsize=(10,6))
sns.lineplot(x='Year', y='Class', data=yearly_success, marker='o')
plt.title('Yearly Trend of Launch Success Rate', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Average Success Rate', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# You can observe that the success rate since 2013 kept increasing till 2017 (stable in 2014) and after 2015 it started increasing.

# %% [markdown]
# ## Features Engineering

# %% [markdown]
# By now, you should obtain some preliminary insights about how each important variable would affect the success rate, we will select the features that will be used in success prediction in the future module.

# %%
features = df[['FlightNumber', 'PayloadMass', 'Orbit', 'LaunchSite', 'Flights', 'GridFins', 'Reused', 'Legs', 'LandingPad', 'Block', 'ReusedCount', 'Serial']]
features.head()
# Out:
#    FlightNumber  PayloadMass Orbit    LaunchSite  Flights  GridFins  Reused  \
# 0             1  6104.959412   LEO  CCAFS SLC 40        1     False   False
# 1             2   525.000000   LEO  CCAFS SLC 40        1     False   False
# 2             3   677.000000   ISS  CCAFS SLC 40        1     False   False
# 3             4   500.000000    PO   VAFB SLC 4E        1     False   False
# 4             5  3170.000000   GTO  CCAFS SLC 40        1     False   False
#
#     Legs LandingPad  Block  ReusedCount Serial
# 0  False        NaN    1.0            0  B0003
# 1  False        NaN    1.0            0  B0005
# 2  False        NaN    1.0            0  B0007
# 3  False        NaN    1.0            0  B1003
# 4  False        NaN    1.0            0  B1004

# %% [markdown]
#  ### Create dummy variables to categorical columns

# %% [markdown]
# Use the function <code>get_dummies</code> and <code>features</code> dataframe to apply OneHotEncoder to the column <code>Orbits</code>, <code>LaunchSite</code>, <code>LandingPad</code>, and <code>Serial</code>. Assign the value to the variable <code>features_one_hot</code>, display the results using the method head. Your result dataframe must include all features including the encoded ones.

# %%
# HINT: Use get_dummies() function on the categorical columns

# Select the relevant features
features = df[['FlightNumber', 'PayloadMass', 'Orbit', 'LaunchSite', 'Flights', 
               'GridFins', 'Reused', 'Legs', 'LandingPad', 'Block', 
               'ReusedCount', 'Serial']]

# Apply OneHotEncoder using get_dummies()
features_one_hot = pd.get_dummies(features, 
                                  columns=['Orbit', 'LaunchSite', 'LandingPad', 'Serial'])

# Display the resulting dataframe
features_one_hot.head()
# Out:
#    FlightNumber  PayloadMass  Flights  GridFins  Reused   Legs  Block  \
# 0             1  6104.959412        1     False   False  False    1.0
# 1             2   525.000000        1     False   False  False    1.0
# 2             3   677.000000        1     False   False  False    1.0
# 3             4   500.000000        1     False   False  False    1.0
# 4             5  3170.000000        1     False   False  False    1.0
#
#    ReusedCount  Orbit_ES-L1  Orbit_GEO  ...  Serial_B1048  Serial_B1049  \
# 0            0        False      False  ...         False         False
# 1            0        False      False  ...         False         False
# 2            0        False      False  ...         False         False
# 3            0        False      False  ...         False         False
# 4            0        False      False  ...         False         False
#
#    Serial_B1050  Serial_B1051  Serial_B1054  Serial_B1056  Serial_B1058  \
# 0         False         False         False         False         False
# 1         False         False         False         False         False
# 2         False         False         False         False         False
# 3         False         False         False         False         False
# 4         False         False         False         False         False
#
#    Serial_B1059  Serial_B1060  Serial_B1062
# 0         False         False         False
# 1         False         False         False
# 2         False         False         False
# 3         False         False         False
# 4         False         False         False
#
# [5 rows x 80 columns]

# %%
features_one_hot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 80 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   FlightNumber                         90 non-null     float64
#  1   PayloadMass                          90 non-null     float64
#  2   Flights                              90 non-null     float64
#  3   GridFins                             90 non-null     float64
#  4   Reused                               90 non-null     float64
#  5   Legs                                 90 non-null     float64
#  6   Block                                90 non-null     float64
#  7   ReusedCount                          90 non-null     float64
#  8   Orbit_ES-L1                          90 non-null     float64
#  9   Orbit_GEO                            90 non-null     float64
#  10  Orbit_GTO                            90 non-null     float64
#  11  Orbit_HEO                            90 non-null     float64
#  12  Orbit_ISS                            90 non-null     float64
#  13  Orbit_LEO                            90 non-null     float64
#  14  Orbit_MEO                            90 non-null     float64
#  15  Orbit_PO                             90 non-null     float64
#  16  Orbit_SO                             90 non-null     float64
#  17  Orbit_SSO                            90 non-null     float64
#  18  Orbit_VLEO                           90 non-null     float64
#  19  LaunchSite_CCAFS SLC 40              90 non-null     float64
#  20  LaunchSite_KSC LC 39A                90 non-null     float64
#  21  LaunchSite_VAFB SLC 4E               90 non-null     float64
#  22  LandingPad_5e9e3032383ecb267a34e7c7  90 non-null     float64
#  23  LandingPad_5e9e3032383ecb554034e7c9  90 non-null     float64
#  24  LandingPad_5e9e3032383ecb6bb234e7ca  90 non-null     float64
#  25  LandingPad_5e9e3032383ecb761634e7cb  90 non-null     float64
#  26  LandingPad_5e9e3033383ecbb9e534e7cc  90 non-null     float64
#  27  Serial_B0003                         90 non-null     float64
#  28  Serial_B0005                         90 non-null     float64
#  29  Serial_B0007                         90 non-null     float64
#  30  Serial_B1003                         90 non-null     float64
#  31  Serial_B1004                         90 non-null     float64
#  32  Serial_B1005                         90 non-null     float64
#  33  Serial_B1006                         90 non-null     float64
#  34  Serial_B1007                         90 non-null     float64
#  35  Serial_B1008                         90 non-null     float64
#  36  Serial_B1010                         90 non-null     float64
#  37  Serial_B1011                         90 non-null     float64
#  38  Serial_B1012                         90 non-null     float64
#  39  Serial_B1013                         90 non-null     float64
#  40  Serial_B1015                         90 non-null     float64
#  41  Serial_B1016                         90 non-null     float64
#  42  Serial_B1017                         90 non-null     float64
#  43  Serial_B1018                         90 non-null     float64
#  44  Serial_B1019                         90 non-null     float64
#  45  Serial_B1020                         90 non-null     float64
#  46  Serial_B1021                         90 non-null     float64
#  47  Serial_B1022                         90 non-null     float64
#  48  Serial_B1023                         90 non-null     float64
#  49  Serial_B1025                         90 non-null     float64
#  50  Serial_B1026                         90 non-null     float64
#  51  Serial_B1028                         90 non-null     float64
#  52  Serial_B1029                         90 non-null     float64
#  53  Serial_B1030                         90 non-null     float64
#  54  Serial_B1031                         90 non-null     float64
#  55  Serial_B1032                         90 non-null     float64
#  56  Serial_B1034                         90 non-null     float64
#  57  Serial_B1035                         90 non-null     float64
#  58  Serial_B1036                         90 non-null     float64
#  59  Serial_B1037                         90 non-null     float64
#  60  Serial_B1038                         90 non-null     float64
#  61  Serial_B1039                         90 non-null     float64
#  62  Serial_B1040                         90 non-null     float64
#  63  Serial_B1041                         90 non-null     float64
#  64  Serial_B1042                         90 non-null     float64
#  65  Serial_B1043                         90 non-null     float64
#  66  Serial_B1044                         90 non-null     float64
#  67  Serial_B1045                         90 non-null     float64
#  68  Serial_B1046                         90 non-null     float64
#  69  Serial_B1047                         90 non-null     float64
#  70  Serial_B1048                         90 non-null     float64
#  71  Serial_B1049                         90 non-null     float64
#  72  Serial_B1050                         90 non-null     float64
#  73  Serial_B1051                         90 non-null     float64
#  74  Serial_B1054                         90 non-null     float64
#  75  Serial_B1056                         90 non-null     float64
#  76  Serial_B1058                         90 non-null     float64
#  77  Serial_B1059                         90 non-null     float64
#  78  Serial_B1060                         90 non-null     float64
#  79  Serial_B1062                         90 non-null     float64
# dtypes: float64(80)
# memory usage: 56.4 KB

# %% [markdown]
# ### Cast all numeric columns to `float64`

# %% [markdown]
# Now that our <code>features_one_hot</code> dataframe only contains numbers cast the entire dataframe to variable type <code>float64</code>

# %%
# HINT: use astype function

# Cast all columns in the dataframe to float64
features_one_hot = features_one_hot.astype('float64')

# Display the updated dataframe
features_one_hot.dtypes.head(20)  # Optional: to verify the data types
# Out:
# FlightNumber               float64
# PayloadMass                float64
# Flights                    float64
# GridFins                   float64
# Reused                     float64
# Legs                       float64
# Block                      float64
# ReusedCount                float64
# Orbit_ES-L1                float64
# Orbit_GEO                  float64
# Orbit_GTO                  float64
# Orbit_HEO                  float64
# Orbit_ISS                  float64
# Orbit_LEO                  float64
# Orbit_MEO                  float64
# Orbit_PO                   float64
# Orbit_SO                   float64
# Orbit_SSO                  float64
# Orbit_VLEO                 float64
# LaunchSite_CCAFS SLC 40    float64
# dtype: object

# %% [markdown]
# We can now export it to a <b>CSV</b> for the next section,but to make the answers consistent, in the next lab we will provide data in a pre-selected date range.

# %% [markdown]
# <code>features_one_hot.to_csv('dataset_part_3.csv', index=False)</code>

# %%
# Export the DataFrame to a CSV file
features_one_hot.to_csv('dataset_part_3.csv', index=False)
